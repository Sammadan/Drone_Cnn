# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3ac22213-bce9-4802-adf8-3d5db2020de4" name="files[]" multiple disabled />
#      <output id="result-3ac22213-bce9-4802-adf8-3d5db2020de4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ssd_inception_v2_coco.config to ssd_inception_v2_coco.config

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !tar -xvf drive/My\ Drive/drone_cnn2.tar.xz
# Out:
# drone_cnn2 (copy)/
# drone_cnn2 (copy)/train.csv
# drone_cnn2 (copy)/ssd_inception_v2_coco.config
# drone_cnn2 (copy)/.gitignore
# drone_cnn2 (copy)/CODE_OF_CONDUCT.md
# drone_cnn2 (copy)/LICENSE
# drone_cnn2 (copy)/README.md
# drone_cnn2 (copy)/requirements.txt
# drone_cnn2 (copy)/setup.py
# drone_cnn2 (copy)/train.record
# drone_cnn2 (copy)/test.csv
# drone_cnn2 (copy)/test.record
# drone_cnn2 (copy)/annotations/
# drone_cnn2 (copy)/annotations/label_map.pbtxt
# drone_cnn2 (copy)/annotations/trainval.txt
# drone_cnn2 (copy)/annotations/xmls/
# drone_cnn2 (copy)/annotations/xmls/videoplayback0051.xml
# drone_cnn2 (copy)/annotations/xmls/videoplayback0057.xml
# drone_cnn2 (copy)/annotations/xmls/videoplayback0084.xml
# drone_cnn2 (copy)/annotations/xmls/videoplayback0090.xml
# drone_cnn2 (copy)/annotations/xmls/videoplayback0096.xml
# drone_cnn2 (copy)/annotations/xmls/videoplayback0102.xml
# drone_cnn2 (copy)/annotations/xmls/videoplayback0108.xml
# ...

# %%
# !cp drone_cnn2\ \(copy\)/object_detection/train.py drone_cnn2\ \(copy\)/train.py

# %%
os.chdir('drone_cnn2 (copy)')
# Out:
# annotations	    requirements.txt		  test.record
# CODE_OF_CONDUCT.md  screenshots			  train
# images		    setup.py			  train.csv
# LICENSE		    slim			  train.py
# object_detection    ssd_inception_v2_coco.config  train.record
# output		    test.csv
# README.md	    test_images

# %%
# !rm ssd_inception_v2_coco.config

# %%
# !cp /content/ssd_inception_v2_coco.config /content/drone_cnn2\ \(copy\)/ssd_inception_v2_coco.config

# %%
# !cp -r slim/deployment/ deployment/

# %%
# !cp -r slim/nets/ nets/

# %%
# !cat ssd_inception_v2_coco.config
# Out:
# # SSD with Inception v2 configuration for MSCOCO Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   ssd {
#     num_classes: 1
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
# ...

# %%
# !cp -r /content/drone_cnn2\ \(copy\) /content/drone_cnn2/

# %%
# !rm -r /content/drone_cnn2\ \(copy\)

# %%
os.chdir('/content/drone_cnn2/')

# %%
# !python train.py         --logtostderr         --train_dir=train         --pipeline_config_path=ssd_inception_v2_coco.config

# %%
# !ls
